# %% [markdown]
# # Eight Draft1

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings
import datetime
import sqlite3

from IPython.display import display
from pylab import rcParams

# %% [markdown]
# # Display Parameters

# %% [markdown]
# ## Display Features

# %%
# %matplotlib inline
pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500
pd.set_option("display.float_format", lambda x: "%.3f" % x)

# %% [markdown]
# ## Colors

# %%
color_1 = "bisque"
color_2 = "crimson"
color_3 = "orangered"
color_4 = "lightcoral"
color_5 = "royalblue"
color_6 = "pink"
color_7 = "indianred"
color_8 = "slategrey"
color_9 = "salmon"

# %% [markdown]
# ## Figure Parameters

# %%
size = 20

params = {
    "font.family": "Times New Roman",
    "font.size": size,
    "axes.labelsize": size,
    "xtick.labelsize": size * 0.75,
    "ytick.labelsize": size * 0.75,
    "figure.titlesize": size * 1.5,
    "axes.titlesize": size * 1.5,
    "axes.titlepad": size,
    "axes.labelpad": size - 10,
    "lines.linewidth": 2,
    "axes.spines.top": False,
    "axes.spines.right": False,
    "axes.spines.left": False,
    "axes.spines.bottom": False,
    "legend.fontsize": size,
}

# %% [markdown]
# # Load Raw Data

# %%
redwine = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\RedWine\\DataSets\\winequality-red.csv",
    index_col=False,
)

# %%
eight = redwine[redwine["quality"] == 8]

# %%
eight
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 267           7.900             0.350        0.460           3.600      0.078
# 278          10.300             0.320        0.450           6.400      0.073
# 390           5.600             0.850        0.050           1.400      0.045
# 440          12.600             0.310        0.720           2.200      0.072
# 455          11.300             0.620        0.670           5.200      0.086
# 481           9.400             0.300        0.560           2.800      0.080
# 495          10.700             0.350        0.530           2.600      0.070
# 498          10.700             0.350        0.530           2.600      0.070
# 588           5.000             0.420        0.240           2.000      0.060
# 828           7.800             0.570        0.090           2.300      0.065
# 1061          9.100             0.400        0.500           1.800      0.071
# 1090         10.000             0.260        0.540           1.900      0.083
# 1120          7.900             0.540        0.340           2.500      0.076
# 1202          8.600             0.420        0.390           1.800      0.068
# 1269          5.500             0.490        0.030           1.800      0.044
# 1403          7.200             0.330        0.330           1.700      0.061
# 1449          7.200             0.380        0.310           2.000      0.056
# 1549          7.400             0.360        0.300           1.800      0.074
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 267                15.000                37.000    0.997 3.350      0.860
# 278                 5.000                13.000    0.998 3.230      0.820
# 390                12.000                88.000    0.992 3.560      0.820
# 440                 6.000                29.000    0.999 2.880      0.820
# 455                 6.000                19.000    0.999 3.220      0.690
# 481                 6.000                17.000    0.996 3.150      0.920
# 495                 5.000                16.000    0.997 3.150      0.650
# 498                 5.000                16.000    0.997 3.150      0.650
# 588                19.000                50.000    0.992 3.720      0.740
# 828                34.000                45.000    0.994 3.460      0.740
# 1061                7.000                16.000    0.995 3.210      0.690
# 1090               42.000                74.000    0.995 2.980      0.630
# 1120                8.000                17.000    0.992 3.200      0.720
# 1202                6.000                12.000    0.995 3.350      0.690
# 1269               28.000                87.000    0.991 3.500      0.820
# 1403                3.000                13.000    0.996 3.230      1.100
# 1449               15.000                29.000    0.995 3.230      0.760
# 1549               17.000                24.000    0.994 3.240      0.700
#
#       alcohol  quality
# 267    12.800        8
# 278    12.600        8
# 390    12.900        8
# 440     9.800        8
# 455    13.400        8
# 481    11.700        8
# 495    11.000        8
# 498    11.000        8
# 588    14.000        8
# 828    12.700        8
# 1061   12.500        8
# 1090   11.800        8
# 1120   13.100        8
# 1202   11.700        8
# 1269   14.000        8
# 1403   10.000        8
# 1449   11.300        8
# 1549   11.400        8

# %%
corr = eight.corr()

mask = np.triu(np.ones_like(corr, dtype = bool))

f, ax = plt.subplots(figsize = (16, 16))

cmap = sns.diverging_palette(230, 10, as_cmap = True)
heatmap = sns.heatmap(
    corr,
    mask=mask,
    cmap=cmap,
    vmax=1,
    vmin=-1,
    center=0,
    square=True,
    linewidths=0.5,
    cbar_kws={"shrink": 0.5},
    annot=True,
)

heatmap.set_title(
    " Red Wine Correlation Heatmap",
    fontdict={"fontsize": 16},
    pad=12,
)
plt.xlabel("")
plt.ylabel("");

# %%
df_eight_sub = eight[['fixed acidity','density','citric acid','pH', 'chlorides', 'quality']]
sns.pairplot(df_eight_sub, hue='quality')
plt.show()
