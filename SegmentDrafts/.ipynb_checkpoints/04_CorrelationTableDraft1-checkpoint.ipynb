# %% [markdown]
# # Correlation Table Draft 1

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings
import datetime
import sqlite3
import imblearn


from IPython.display import display
from pylab import rcParams
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score
from imblearn.over_sampling import RandomOverSampler
from imblearn.pipeline import Pipeline
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %% [markdown]
# # Load Raw Data

# %%
redwine = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\RedWine\\DataSets\\winequality-red.csv",
    index_col=False,
)

# %%
pd.options.display.max_rows = 999
redwine.corr().unstack().sort_values().drop_duplicates().to_frame()
# Out:
#                                                   0
# pH                   fixed acidity        -0.682978
# volatile acidity     citric acid          -0.552496
# pH                   citric acid          -0.541904
# alcohol              density              -0.496180
# volatile acidity     quality              -0.390558
# density              pH                   -0.341699
# chlorides            pH                   -0.265026
# sulphates            volatile acidity     -0.260987
# volatile acidity     fixed acidity        -0.256131
# chlorides            alcohol              -0.221141
# total sulfur dioxide alcohol              -0.205654
# alcohol              volatile acidity     -0.202288
# sulphates            pH                   -0.196648
# total sulfur dioxide quality              -0.185100
# quality              density              -0.174919
# fixed acidity        free sulfur dioxide  -0.153794
# quality              chlorides            -0.128907
# ...

# %%
abs(redwine["fixed acidity"].corr(redwine["citric acid"]))
# Out:
# 0.6717034347641059

# %%
abs(redwine["quality"].corr(redwine["citric acid"]))
# Out:
# 0.22637251431804142
